# %%
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

# %%
photo = Image.open("Sample_FOV.tif")
photo.show() # Opens my pngs and shows the image

# %%
photo = np.array(photo)
plt.imshow(photo)
